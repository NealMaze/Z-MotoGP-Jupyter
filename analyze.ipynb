# %%
from lists import *
from B2_ConverterHelpers import getFiles

errorFiles = []

# combine years and leagues into separate files
for yr in yrs:
    for lge in lges:
        files = getFiles(csvSesDir, f"{yr}-{lge}*.csv")
        if len(files) > 0:
            frames = []
            lenGoal = 0

            for file in files:
                xdf = pd.read_csv(file)
                df = xdf.drop(["sec_fiv", "sec_six", "sec_sev", "sec_eig"], axis = 1)
                
                df["lap_sec"] = df["lap_time"].apply(toSecs)
                df["one_seconds"] = df["sec_one"].apply(toSecs)
                df["two_seconds"] = df["sec_two"].apply(toSecs)
                df["thr_seconds"] = df["sec_thr"].apply(toSecs)
                df["four_seconds"] = df["sec_four"].apply(toSecs)
                
                #####
                # remove outliers here before normalizing the data
                
                
                #####
                
                df["lap_scaled"] = df["lap_sec"] / df["lap_sec"].abs().max()
                df["one_scaled"] = df["one_seconds"] / df["one_seconds"].abs().max()
                df["two_scaled"] = df["two_seconds"] / df["two_seconds"].abs().max()
                df["thr_scaled"] = df["thr_seconds"] / df["thr_seconds"].abs().max()
                df["four_scaled"] = df["four_seconds"] / df["four_seconds"].abs().max()
                
                frames.append(df)
                lenGoal = lenGoal + len(df)
            
            wholeFrame = pd.concat(frames)

            nueFile = f"{yr}-{lge}-Season"
            wholeFrame.to_csv(f"{csvSeasonDir}{nueFile}.csv", index = False)
            lenActual = len(wholeFrame)
            print(f"{nueFile}")
            if lenActual != lenGoal:
                print(f"\nerror \n{nueFile}\ngoal length:  {lenGoal}\nactual length:  {lenActual}\nend error\n")
                errorFiles.append(nueFile)
        
if len(errorFiles) != 0:
    print("\n\nError Files:")
    for i in errorFiles:
        print(i)

print("\nFinished\n\n")
# Out:
# 2021-MotoGP-Season
#
# Finished

# %%
from lists import *
import pandas as pd
from matplotlib import pyplot as plt
from B2_ConverterHelpers import getFiles
from scipy.stats import norm
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)

print("\nFinished\n")
# Out:
# Finished

# %%
errorFiles = []

sesTypes = ["FP1", "FP2", "FP3", "FP4", "Q1", "Q2", "WUP", "RAC"]

# combine years and leagues into separate files
for yr in yrs:
    for lge in lges[:1]:
        files = getFiles(csvSesDir, f"{yr}-{lge}*.csv")
        if len(files) > 0:
            frames = []
            lenGoal = 0

            for file in files:
                xdf = pd.read_csv(file)
                df = xdf.drop(["sec_fiv", "sec_six", "sec_sev", "sec_eig"], axis = 1)
                
                df["lap_sec"] = df["lap_time"].apply(toSecs)
                df["one_seconds"] = df["sec_one"].apply(toSecs)
                df["two_seconds"] = df["sec_two"].apply(toSecs)
                df["thr_seconds"] = df["sec_thr"].apply(toSecs)
                df["four_seconds"] = df["sec_four"].apply(toSecs)
                
#                 for i in sesTypes:
#                     if i in file:
#                         print(i)
                if "RAC" in file:
#                     print(file)
#                     print(f"fastest lap = {df.lap_sec.min()}")
#                     print(f"slowest lap = {df.lap_sec.max()}")
                    if df.lap_sec.std() > 3:
                        print("")
                        print(f"fastest lap = {df.lap_sec.min()}")
                        print(f"slowest lap = {df.lap_sec.max()}")
                        print(f"standard deviation = {df.lap_sec.std()}")
#                     print("")
                
                #####
                # remove outliers here before normalizing the data
                
                
                #####
                
print("\n\nFinished\n")
# Out:
# fastest lap = 103.301
# slowest lap = 151.844
# standard deviation = 4.317069806192553
#
# fastest lap = 91.884
# slowest lap = 144.094
# standard deviation = 3.7586649405243193
#
# fastest lap = 115.039
# slowest lap = 197.002
# standard deviation = 4.135028134645157
#
# fastest lap = 119.936
# slowest lap = 189.977
# standard deviation = 4.648282950254391
#
# fastest lap = 93.35499999999999
# slowest lap = 173.49099999999999
# standard deviation = 3.9952965138938556
#
# fastest lap = 89.254
# slowest lap = 355.735
# standard deviation = 31.639952609102615
#
# fastest lap = 92.35499999999999
# slowest lap = 236.451
# standard deviation = 7.659369006337629
#
# fastest lap = 100.507
# slowest lap = 396.967
# standard deviation = 16.455285963434253
#
# fastest lap = 93.712
# slowest lap = 147.8
# standard deviation = 3.315838829422528
#
# fastest lap = 116.64
# slowest lap = 528.917
# standard deviation = 19.795487309943386
#
# fastest lap = 91.471
# slowest lap = 175.28199999999998
# standard deviation = 4.532608846785175
#
# fastest lap = 105.646
# slowest lap = 160.81799999999998
# standard deviation = 3.3860181454974416
#
# fastest lap = 120.762
# slowest lap = 171.631
# standard deviation = 3.1548563662968454
#
# fastest lap = 101.97200000000001
# slowest lap = 139.245
# standard deviation = 4.090957774312622
#
# fastest lap = 99.15899999999999
# slowest lap = 177.817
# standard deviation = 4.082942474074942
#
# fastest lap = 92.312
# slowest lap = 157.297
# standard deviation = 4.130923734817644
#
# fastest lap = 108.001
# slowest lap = 375.897
# standard deviation = 13.025795242768776
#
# fastest lap = 100.021
# slowest lap = 365.557
# standard deviation = 13.746928288740559
#
# fastest lap = 94.113
# slowest lap = 192.49
# standard deviation = 4.461504090024852
#
# fastest lap = 115.99000000000001
# slowest lap = 165.543
# standard deviation = 3.151311098978272
#
# fastest lap = 117.05199999999999
# slowest lap = 224.935
# standard deviation = 10.325439236385046
#
# fastest lap = 107.069
# slowest lap = 200.155
# standard deviation = 5.651234937006005
#
# fastest lap = 116.568
# slowest lap = 161.435
# standard deviation = 3.663883106575347
#
# fastest lap = 85.273
# slowest lap = 183.426
# standard deviation = 5.867775152132121
#
# fastest lap = 91.576
# slowest lap = 178.869
# standard deviation = 4.3374325185706155
#
# fastest lap = 124.899
# slowest lap = 450.404
# standard deviation = 16.75511141967836
#
# fastest lap = 94.61699999999999
# slowest lap = 136.793
# standard deviation = 4.904627595113053
#
# fastest lap = 84.561
# slowest lap = 154.054
# standard deviation = 5.103967174174517
#
# fastest lap = 128.216
# slowest lap = 214.243
# standard deviation = 8.079323137721111
#
# fastest lap = 122.339
# slowest lap = 166.57999999999998
# standard deviation = 3.145025488666816
#
# fastest lap = 90.876
# slowest lap = 548.839
# standard deviation = 20.18630818498997
#
# fastest lap = 105.576
# slowest lap = 167.358
# standard deviation = 3.6271445373179962
#
# fastest lap = 131.95
# slowest lap = 163.96699999999998
# standard deviation = 3.499506075988358
#
# fastest lap = 100.243
# slowest lap = 188.588
# standard deviation = 8.338436106928501
#
# fastest lap = 124.682
# slowest lap = 173.945
# standard deviation = 4.396032459056463
#
# fastest lap = 93.293
# slowest lap = 186.325
# standard deviation = 4.852206072733485
#
# fastest lap = 105.971
# slowest lap = 172.223
# standard deviation = 3.8782249815221577
#
# fastest lap = 108.339
# slowest lap = 270.783
# standard deviation = 10.827408331325968
#
# fastest lap = 85.019
# slowest lap = 257.814
# standard deviation = 12.039992671849442
#
# fastest lap = 115.267
# slowest lap = 452.649
# standard deviation = 14.812883135074015
#
# fastest lap = 136.486
# slowest lap = 292.878
# standard deviation = 10.596104679062295
#
# fastest lap = 93.273
# slowest lap = 474.513
# standard deviation = 18.350135556163718
#
# fastest lap = 114.86699999999999
# slowest lap = 168.94400000000002
# standard deviation = 3.835896468142901
#
# fastest lap = 89.28
# slowest lap = 543.823
# standard deviation = 18.019854628182657
#
# fastest lap = 120.606
# slowest lap = 169.411
# standard deviation = 3.4216540895899774
#
# fastest lap = 92.87899999999999
# slowest lap = 149.828
# standard deviation = 3.3585886357562056
#
# fastest lap = 102.219
# slowest lap = 184.027
# standard deviation = 6.8436235889516635
#
# fastest lap = 81.53
# slowest lap = 404.318
# standard deviation = 12.818001141650768
#
# fastest lap = 92.831
# slowest lap = 163.763
# standard deviation = 4.726358265836904
#
# fastest lap = 116.027
# slowest lap = 187.141
# standard deviation = 3.877239624321996
#
# fastest lap = 121.98
# slowest lap = 281.866
# standard deviation = 7.817358095051072
#
# fastest lap = 94.108
# slowest lap = 168.09
# standard deviation = 3.5400271911988046
#
# fastest lap = 109.107
# slowest lap = 257.283
# standard deviation = 14.266294934377196
#
# fastest lap = 121.15
# slowest lap = 152.822
# standard deviation = 3.1096858530669915
#
# fastest lap = 91.515
# slowest lap = 131.893
# standard deviation = 3.757053583996058
#
# fastest lap = 123.575
# slowest lap = 178.136
# standard deviation = 3.2978916713687654
#
# fastest lap = 99.84100000000001
# slowest lap = 211.453
# standard deviation = 5.1959317863519505
#
# fastest lap = 94.575
# slowest lap = 166.519
# standard deviation = 10.23879056939647
#
# fastest lap = 82.037
# slowest lap = 116.37899999999999
# standard deviation = 3.2827389612399918
#
# fastest lap = 116.13499999999999
# slowest lap = 209.505
# standard deviation = 5.597172959558589
#
# fastest lap = 121.415
# slowest lap = 149.641
# standard deviation = 3.5262235475857993
#
# fastest lap = 88.108
# slowest lap = 194.839
# standard deviation = 10.364297311935303
#
# fastest lap = 105.73599999999999
# slowest lap = 162.385
# standard deviation = 3.806381999232086
#
# fastest lap = 103.59700000000001
# slowest lap = 152.399
# standard deviation = 4.200638985701082
#
# fastest lap = 102.55199999999999
# slowest lap = 180.14
# standard deviation = 4.504080237102648
#
# fastest lap = 81.539
# slowest lap = 688.452
# standard deviation = 24.951917748574324
#
# fastest lap = 115.541
# slowest lap = 901.532
# standard deviation = 37.762711879329125
#
# fastest lap = 109.10900000000001
# slowest lap = 159.606
# standard deviation = 3.4408862218258145
#
# fastest lap = 105.589
# slowest lap = 144.926
# standard deviation = 3.0537929247048416
#
# fastest lap = 134.67
# slowest lap = 189.283
# standard deviation = 5.614150013384662
#
# fastest lap = 93.119
# slowest lap = 149.577
# standard deviation = 8.062397395341325
#
# fastest lap = 100.019
# slowest lap = 162.129
# standard deviation = 3.815891294553637
#
# fastest lap = 96.90899999999999
# slowest lap = 192.827
# standard deviation = 4.73088296660504
#
# fastest lap = 104.614
# slowest lap = 258.77
# standard deviation = 10.038700933437989
#
# fastest lap = 102.642
# slowest lap = 190.541
# standard deviation = 4.54462788695925
#
# fastest lap = 122.888
# slowest lap = 188.782
# standard deviation = 5.012137834134986
#
# fastest lap = 94.548
# slowest lap = 159.149
# standard deviation = 4.083035985944878
#
# fastest lap = 107.705
# slowest lap = 144.507
# standard deviation = 3.346226156026972
#
# fastest lap = 117.191
# slowest lap = 190.599
# standard deviation = 5.5744002989439
#
# fastest lap = 99.807
# slowest lap = 256.83299999999997
# standard deviation = 7.732648022015358
#
# fastest lap = 93.906
# slowest lap = 219.11599999999999
# standard deviation = 6.319601290851291
#
# fastest lap = 106.09
# slowest lap = 136.668
# standard deviation = 3.1386492324299753
#
# fastest lap = 90.629
# slowest lap = 249.202
# standard deviation = 9.879354348495145
#
# fastest lap = 94.167
# slowest lap = 130.932
# standard deviation = 3.873213473254618
#
# fastest lap = 108.753
# slowest lap = 231.918
# standard deviation = 7.485957413855142
#
# fastest lap = 93.61699999999999
# slowest lap = 198.085
# standard deviation = 6.731565277393095
#
# fastest lap = 141.432
# slowest lap = 162.743
# standard deviation = 3.9261717630352337
#
# fastest lap = 95.24000000000001
# slowest lap = 297.803
# standard deviation = 11.604010227797799
#
# fastest lap = 117.524
# slowest lap = 159.97
# standard deviation = 3.0115308821829974
#
# fastest lap = 100.896
# slowest lap = 206.494
# standard deviation = 5.651953846093179
#
# fastest lap = 94.34
# slowest lap = 141.972
# standard deviation = 3.4476457861996392
#
# fastest lap = 122.117
# slowest lap = 758.568
# standard deviation = 39.57144861381186
#
# fastest lap = 99.731
# slowest lap = 343.702
# standard deviation = 12.682664865575566
#
# fastest lap = 103.154
# slowest lap = 169.327
# standard deviation = 3.628398484264694
#
# fastest lap = 82.256
# slowest lap = 140.37
# standard deviation = 4.866233506826204
#
# fastest lap = 91.554
# slowest lap = 125.574
# standard deviation = 4.765305343845618
#
# fastest lap = 100.152
# slowest lap = 143.375
# standard deviation = 3.4708257331585592
# fastest lap = 133.694
# slowest lap = 154.542
# standard deviation = 3.510856149921766
#
# fastest lap = 108.477
# slowest lap = 665.915
# standard deviation = 28.90978427503628
#
# fastest lap = 95.045
# slowest lap = 240.967
# standard deviation = 12.52315871952163
#
# fastest lap = 111.186
# slowest lap = 171.887
# standard deviation = 9.301658641805865
#
# fastest lap = 115.15299999999999
# slowest lap = 210.261
# standard deviation = 5.162388601820528
#
# fastest lap = 92.749
# slowest lap = 162.18099999999998
# standard deviation = 4.3804922559729675
#
# fastest lap = 109.668
# slowest lap = 130.329
# standard deviation = 3.2997729536299274
#
# fastest lap = 122.249
# slowest lap = 176.602
# standard deviation = 3.6373416488761525
#
# fastest lap = 94.215
# slowest lap = 183.362
# standard deviation = 6.351565474804605
#
# fastest lap = 83.082
# slowest lap = 308.466
# standard deviation = 11.93619889666415
#
# fastest lap = 82.542
# slowest lap = 297.074
# standard deviation = 12.48499808584317
#
# fastest lap = 118.301
# slowest lap = 198.19
# standard deviation = 4.434238957988056
#
# fastest lap = 94.649
# slowest lap = 148.733
# standard deviation = 3.4951384269723174
#
# fastest lap = 97.493
# slowest lap = 195.686
# standard deviation = 4.897759891087911
#
# fastest lap = 110.718
# slowest lap = 207.24099999999999
# standard deviation = 10.055450552314804
#
# fastest lap = 100.905
# slowest lap = 185.584
# standard deviation = 4.438778021064861
#
# fastest lap = 98.678
# slowest lap = 245.505
# standard deviation = 10.797200932218903
#
# fastest lap = 101.428
# slowest lap = 235.059
# standard deviation = 8.256079219139457
#
# fastest lap = 101.24799999999999
# slowest lap = 152.195
# standard deviation = 3.0954913413930347
#
# fastest lap = 83.333
# slowest lap = 132.332
# standard deviation = 3.8043048803568893
#
# fastest lap = 90.917
# slowest lap = 198.101
# standard deviation = 12.981735089284237
#
# fastest lap = 97.914
# slowest lap = 318.793
# standard deviation = 12.350478757875885
#
# fastest lap = 92.924
# slowest lap = 645.18
# standard deviation = 42.98564347240369
#
# fastest lap = 112.87700000000001
# slowest lap = 631.737
# standard deviation = 27.994669449530218
#
# fastest lap = 119.318
# slowest lap = 216.618
# standard deviation = 5.122544866800256
#
# fastest lap = 95.087
# slowest lap = 207.56
# standard deviation = 7.729354862325636
#
# fastest lap = 103.048
# slowest lap = 190.238
# standard deviation = 5.219100209996615
#
# fastest lap = 97.106
# slowest lap = 284.43399999999997
# standard deviation = 9.421512965042494
#
# fastest lap = 88.714
# slowest lap = 170.78199999999998
# standard deviation = 4.126215003060128
#
# fastest lap = 100.596
# slowest lap = 221.077
# standard deviation = 6.682938811393097
#
# fastest lap = 107.968
# slowest lap = 149.731
# standard deviation = 3.398303167543626
#
# fastest lap = 117.90299999999999
# slowest lap = 222.89600000000002
# standard deviation = 5.952223457897528
#
# fastest lap = 90.332
# slowest lap = 228.427
# standard deviation = 6.944713995400129
#
# fastest lap = 113.11099999999999
# slowest lap = 203.897
# standard deviation = 4.849203424468129
#
# fastest lap = 98.47999999999999
# slowest lap = 405.261
# standard deviation = 14.734836826902725
#
# fastest lap = 133.716
# slowest lap = 199.827
# standard deviation = 5.475404877792835
#
# fastest lap = 93.678
# slowest lap = 180.445
# standard deviation = 4.583560752754197
#
# fastest lap = 110.11699999999999
# slowest lap = 228.314
# standard deviation = 5.966124906232214
#
# fastest lap = 103.195
# slowest lap = 208.555
# standard deviation = 6.704961189101864
#
# fastest lap = 105.37700000000001
# slowest lap = 241.357
# standard deviation = 9.205145291122296
#
# fastest lap = 93.208
# slowest lap = 263.515
# standard deviation = 7.5845087894307985
#
# fastest lap = 108.524
# slowest lap = 129.314
# standard deviation = 3.2629256308697245
#
# fastest lap = 119.293
# slowest lap = 135.337
# standard deviation = 3.018625961643643
#
# fastest lap = 123.253
# slowest lap = 187.776
# standard deviation = 5.071262916183809
#
# fastest lap = 91.102
# slowest lap = 341.587
# standard deviation = 10.427282641365409
#
# fastest lap = 93.582
# slowest lap = 219.81
# standard deviation = 5.405007821777756
#
# fastest lap = 113.50800000000001
# slowest lap = 215.849
# standard deviation = 6.21388861437315
#
# fastest lap = 94.088
# slowest lap = 373.77
# standard deviation = 12.718792196888929
#
# fastest lap = 111.13300000000001
# slowest lap = 144.349
# standard deviation = 3.069161233144792
#
# fastest lap = 104.64099999999999
# slowest lap = 298.362
# standard deviation = 11.565824608806354
#
# fastest lap = 119.47200000000001
# slowest lap = 145.992
# standard deviation = 3.1147906698427485
#
# fastest lap = 124.97
# slowest lap = 209.012
# standard deviation = 4.966305976920865
#
# fastest lap = 110.453
# slowest lap = 288.016
# standard deviation = 8.186715897941458
#
# fastest lap = 108.88499999999999
# slowest lap = 154.628
# standard deviation = 3.191130913077087
#
# fastest lap = 123.822
# slowest lap = 154.285
# standard deviation = 3.3526832249575116
#
# fastest lap = 91.42099999999999
# slowest lap = 138.887
# standard deviation = 3.257070925006771
#
# fastest lap = 131.805
# slowest lap = 189.72899999999998
# standard deviation = 7.533928670864944
#
#
# Finished

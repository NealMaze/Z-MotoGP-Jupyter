# %%
### final not ready



from lists import *
from jupyterHelpers import *

errorFiles = []

# combine years and leagues into separate files
for yr in yrs:
    for lge in lges:
        files = getFiles(csvSesDir, f"{yr}-{lge}*.csv")
        if len(files) > 0:
            frames = []
            lenGoal = 0

            for file in files:
                xdf = pd.read_csv(file)
                df = xdf.drop(["sec_fiv", "sec_six", "sec_sev", "sec_eig"], axis = 1)
                
                df["lap_sec"] = df["lap_time"].apply(toSecs)
                df["one_seconds"] = df["sec_one"].apply(toSecs)
                df["two_seconds"] = df["sec_two"].apply(toSecs)
                df["thr_seconds"] = df["sec_thr"].apply(toSecs)
                df["four_seconds"] = df["sec_four"].apply(toSecs)
                
                #####
                # remove outliers here before normalizing the data
                
                
                #####
                
                df["lap_scaled"] = df["lap_sec"] / df["lap_sec"].abs().max()
                df["one_scaled"] = df["one_seconds"] / df["one_seconds"].abs().max()
                df["two_scaled"] = df["two_seconds"] / df["two_seconds"].abs().max()
                df["thr_scaled"] = df["thr_seconds"] / df["thr_seconds"].abs().max()
                df["four_scaled"] = df["four_seconds"] / df["four_seconds"].abs().max()
                
                frames.append(df)
                lenGoal = lenGoal + len(df)
            
            wholeFrame = pd.concat(frames)

            nueFile = f"{yr}-{lge}-Season"
            wholeFrame.to_csv(f"{csvSeasonDir}{nueFile}.csv", index = False)
            lenActual = len(wholeFrame)
            print(f"{nueFile}")
            if lenActual != lenGoal:
                print(f"\nerror \n{nueFile}\ngoal length:  {lenGoal}\nactual length:  {lenActual}\nend error\n")
                errorFiles.append(nueFile)
        
if len(errorFiles) != 0:
    print("\n\nError Files:")
    for i in errorFiles:
        print(i)

print("\nFinished\n\n")

# %%
from lists import *
import pandas as pd
from matplotlib import pyplot as plt
from jupyterHelpers import *
from scipy.stats import norm
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)

print("Finished")
# Out:
# Finished

# %%
errorFiles = []

sesTypes = ["FP1", "FP2", "FP3", "FP4", "Q1", "Q2", "WUP", "RAC"]

# combine years and leagues into separate files
for yr in yrs[2:3]:
    for lge in lges[:1]:
        files = getFiles(csvSesDir, f"{yr}-{lge}*.csv")
        if len(files) > 0:
            frames = []
            lenGoal = 0

            for file in files:
                xdf = pd.read_csv(file)
                df = xdf.drop(["sec_fiv", "sec_six", "sec_sev", "sec_eig"], axis = 1)
                
                df["lap_sec"] = df["lap_time"].apply(toSecs)
                df["one_seconds"] = df["sec_one"].apply(toSecs)
                df["two_seconds"] = df["sec_two"].apply(toSecs)
                df["thr_seconds"] = df["sec_thr"].apply(toSecs)
                df["four_seconds"] = df["sec_four"].apply(toSecs)
                
                ##########
                upLim = df.lap_sec.mean() + 3 * df.lap_sec.std()
                lowLim = df.lap_sec.mean() - 3 * df.lap_sec.std()
                
                
                
                if df.lap_sec.std() > 3:
                    if df.lap_sec.min() < lowLim:
                        print(file)
                        print("###  REMOVING FAST LAPS  ###")
                        print(f"fastest lap = {df.lap_sec.min()}")
                        print(f"excluded under {lowLim}\n")

                    if df.lap_sec.max() > upLim:
                        print(file)
                        print(f"fastest lap = {df.lap_sec.min()}")
                        print(f"slowest lap = {df.lap_sec.max()}")
                        print(f"excluded over {upLim}\n\n")
                
                ##########                            
                        
                    
#                     if "RAC" in file:
#                     if df.lap_sec.std() > 3:
#                         nueDF = df[(df.lap_sec>upLim) | (df.lap_sec<lowLim)]
#                         print(file)
#                         print(f"fastest lap = {df.lap_sec.min()}")
#                         print(f"excluded under {lowLim}")
#                         print(f"slowest lap = {df.lap_sec.max()}")
#                         print(f"excluded over {upLim}")
#                         print("")
                
                #####
                # remove outliers here before normalizing the data
                
                
                #####
                
print("\n\nFinished\n")
# Out:
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_1-Losail International Circuit-FP1-Analysis.csv
# fastest lap = 113.949
# slowest lap = 1020.659
# excluded over 267.14646133576605
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_1-Losail International Circuit-FP2-Analysis.csv
# fastest lap = 113.38
# slowest lap = 731.257
# excluded over 219.83704166466657
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_1-Losail International Circuit-FP3-Analysis.csv
# fastest lap = 114.229
# slowest lap = 876.498
# excluded over 283.30900462192994
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_1-Losail International Circuit-FP4-Analysis.csv
# fastest lap = 114.616
# slowest lap = 624.7139999999999
# excluded over 249.55710483999937
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_1-Losail International Circuit-Q1-Analysis.csv
# fastest lap = 114.27000000000001
# slowest lap = 220.852
# excluded over 179.26994479408606
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_1-Losail International Circuit-Q2-Analysis.csv
# fastest lap = 113.54599999999999
# slowest lap = 175.611
# excluded over 152.86938119117252
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_1-Losail International Circuit-RAC-Analysis.csv
# fastest lap = 115.039
# slowest lap = 197.002
# excluded over 129.37194511079613
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_1-Losail International Circuit-WUP-Analysis.csv
# fastest lap = 114.587
# slowest lap = 188.689
# excluded over 159.00016492060308
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_10-Automotodrom Brno-FP1-Analysis.csv
# fastest lap = 116.919
# slowest lap = 683.779
# excluded over 534.7131615655072
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_10-Automotodrom Brno-FP2-Analysis.csv
# fastest lap = 115.80199999999999
# slowest lap = 690.103
# excluded over 507.5402249501169
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_10-Automotodrom Brno-FP3-Analysis.csv
# fastest lap = 124.279
# slowest lap = 1646.32
# excluded over 691.9866177871371
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_10-Automotodrom Brno-FP4-Analysis.csv
# fastest lap = 123.779
# slowest lap = 668.589
# excluded over 398.90789985592903
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_10-Automotodrom Brno-Q2-Analysis.csv
# fastest lap = 122.753
# slowest lap = 279.554
# excluded over 251.490077017929
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_10-Automotodrom Brno-WUP-Analysis.csv
# fastest lap = 117.05199999999999
# slowest lap = 331.714
# excluded over 191.2284610471549
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_11-Red Bull Ring-FP1-Analysis.csv
# fastest lap = 84.033
# slowest lap = 770.684
# excluded over 467.89371156728885
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_11-Red Bull Ring-FP2-Analysis.csv
# fastest lap = 83.916
# slowest lap = 626.626
# excluded over 440.16155472873754
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_11-Red Bull Ring-FP3-Analysis.csv
# fastest lap = 83.251
# slowest lap = 779.16
# excluded over 443.04554049148527
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_11-Red Bull Ring-FP4-Analysis.csv
# fastest lap = 83.983
# slowest lap = 471.198
# excluded over 317.48449131589916
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_11-Red Bull Ring-Q1-Analysis.csv
# fastest lap = 83.82900000000001
# slowest lap = 279.163
# excluded over 228.52072402865699
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_11-Red Bull Ring-Q2-Analysis.csv
# fastest lap = 83.027
# slowest lap = 304.63
# excluded over 234.5325727034079
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_11-Red Bull Ring-WUP-Analysis.csv
# fastest lap = 88.803
# slowest lap = 711.912
# excluded over 498.7552408377314
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_12-Silverstone Circuit-FP1-Analysis.csv
# fastest lap = 119.952
# slowest lap = 751.357
# excluded over 535.0515961017493
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_12-Silverstone Circuit-FP2-Analysis.csv
# fastest lap = 119.225
# slowest lap = 865.92
# excluded over 571.8838976116001
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_12-Silverstone Circuit-FP3-Analysis.csv
# fastest lap = 118.547
# slowest lap = 765.65
# excluded over 494.902047561638
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_12-Silverstone Circuit-FP4-Analysis.csv
# fastest lap = 119.327
# slowest lap = 536.91
# excluded over 378.30302331603684
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_12-Silverstone Circuit-Q1-Analysis.csv
# fastest lap = 118.944
# slowest lap = 367.468
# excluded over 322.6144250948912
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_12-Silverstone Circuit-Q2-Analysis.csv
# fastest lap = 118.168
# slowest lap = 347.93399999999997
# excluded over 292.7377927057627
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_12-Silverstone Circuit-RAC-Analysis.csv
# fastest lap = 119.936
# slowest lap = 189.977
# excluded over 136.43299285076313
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_12-Silverstone Circuit-WUP-Analysis.csv
# fastest lap = 119.60900000000001
# slowest lap = 362.447
# excluded over 208.86699966739832
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_13-Misano World Circuit-FP1-Analysis.csv
# fastest lap = 89.431
# slowest lap = 322.112
# excluded over 145.66086544711413
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_13-Misano World Circuit-FP2-Analysis.csv
# fastest lap = 89.169
# slowest lap = 188.985
# excluded over 132.84567517673253
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_13-Misano World Circuit-FP3-Analysis.csv
# fastest lap = 88.64
# slowest lap = 693.881
# excluded over 214.97739373758492
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_13-Misano World Circuit-FP4-Analysis.csv
# fastest lap = 89.26
# slowest lap = 233.089
# excluded over 138.51324771179912
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_13-Misano World Circuit-Q1-Analysis.csv
# fastest lap = 91.526
# slowest lap = 151.79500000000002
# excluded over 150.65248664932113
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_13-Misano World Circuit-Q2-Analysis.csv
# fastest lap = 88.52199999999999
# slowest lap = 143.525
# excluded over 143.3811318742878
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_13-Misano World Circuit-RAC-Analysis.csv
# fastest lap = 93.35499999999999
# slowest lap = 173.49099999999999
# excluded over 107.59171625648297
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_13-Misano World Circuit-WUP-Analysis.csv
# fastest lap = 89.041
# slowest lap = 165.234
# excluded over 131.00868184471022
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_14-MotorLand Aragón-FP1-Analysis.csv
# fastest lap = 106.869
# slowest lap = 845.679
# excluded over 510.9774306873686
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_14-MotorLand Aragón-FP2-Analysis.csv
# fastest lap = 108.01400000000001
# slowest lap = 804.045
# excluded over 501.6046058744437
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_14-MotorLand Aragón-FP3-Analysis.csv
# fastest lap = 115.934
# slowest lap = 2821.8
# excluded over 1853.3358550578155
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_14-MotorLand Aragón-FP4-Analysis.csv
# fastest lap = 108.24600000000001
# slowest lap = 507.81
# excluded over 341.85788270508385
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_14-MotorLand Aragón-Q1-Analysis.csv
# fastest lap = 108.292
# slowest lap = 333.051
# excluded over 288.33704605202
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_14-MotorLand Aragón-Q2-Analysis.csv
# fastest lap = 107.009
# slowest lap = 778.565
# excluded over 415.6529697907615
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_14-MotorLand Aragón-WUP-Analysis.csv
# fastest lap = 119.11099999999999
# slowest lap = 1151.969
# excluded over 697.5871824920847
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_15-Chang International Circuit-FP1-Analysis.csv
# fastest lap = 90.979
# slowest lap = 679.984
# excluded over 496.59052407828597
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_15-Chang International Circuit-FP2-Analysis.csv
# fastest lap = 90.404
# slowest lap = 765.6659999999999
# excluded over 515.177290940618
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_15-Chang International Circuit-FP3-Analysis.csv
# fastest lap = 96.25
# slowest lap = 1671.574
# excluded over 648.0138462021005
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_15-Chang International Circuit-FP4-Analysis.csv
# fastest lap = 90.755
# slowest lap = 636.676
# excluded over 337.36692510142035
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_15-Chang International Circuit-Q1-Analysis.csv
# fastest lap = 90.685
# slowest lap = 296.948
# excluded over 236.6207930920517
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_15-Chang International Circuit-Q2-Analysis.csv
# fastest lap = 89.719
# slowest lap = 717.746
# excluded over 379.75656162735413
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_15-Chang International Circuit-WUP-Analysis.csv
# fastest lap = 90.801
# slowest lap = 626.889
# excluded over 219.99198991281952
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_16-Twin Ring Motegi-FP1-Analysis.csv
# fastest lap = 99.638
# slowest lap = 172.641
# excluded over 139.83482519339026
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_16-Twin Ring Motegi-FP2-Analysis.csv
# fastest lap = 98.654
# slowest lap = 730.879
# excluded over 209.54136801382379
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_16-Twin Ring Motegi-FP3-Analysis.csv
# fastest lap = 109.854
# slowest lap = 504.978
# excluded over 206.31451031155015
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_16-Twin Ring Motegi-FP4-Analysis.csv
# fastest lap = 108.404
# slowest lap = 1289.232
# excluded over 397.645014055608
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_16-Twin Ring Motegi-Q1-Analysis.csv
# fastest lap = 102.612
# slowest lap = 229.652
# excluded over 174.53624050250582
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_16-Twin Ring Motegi-Q2-Analysis.csv
# fastest lap = 101.017
# slowest lap = 156.649
# excluded over 139.91944189119914
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_16-Twin Ring Motegi-WUP-Analysis.csv
# fastest lap = 99.47999999999999
# slowest lap = 156.079
# excluded over 136.35293397977364
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_17-Phillip Island-FP1-Analysis.csv
# fastest lap = 96.489
# slowest lap = 659.728
# excluded over 202.163686813901
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_17-Phillip Island-FP2-Analysis.csv
# fastest lap = 85.729
# slowest lap = 161.643
# excluded over 124.5794098689575
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_17-Phillip Island-FP3-Analysis.csv
# fastest lap = 91.338
# slowest lap = 3007.09
# excluded over 1342.4299355230637
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_17-Phillip Island-FP4-Analysis.csv
# fastest lap = 91.185
# slowest lap = 239.802
# excluded over 164.7647672985136
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_17-Phillip Island-Q1-Analysis.csv
# fastest lap = 86.365
# slowest lap = 216.017
# excluded over 171.50421544815435
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_17-Phillip Island-Q2-Analysis.csv
# fastest lap = 85.765
# slowest lap = 163.637
# excluded over 140.5473488414312
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_17-Phillip Island-RAC-Analysis.csv
# fastest lap = 89.254
# slowest lap = 355.735
# excluded over 195.97708699397447
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_17-Phillip Island-WUP-Analysis.csv
# fastest lap = 87.312
# slowest lap = 154.576
# excluded over 131.69427681857337
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_18-Sepang International Circuit-FP1-Analysis.csv
# fastest lap = 119.027
# slowest lap = 791.847
# excluded over 580.718054702192
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_18-Sepang International Circuit-FP2-Analysis.csv
# fastest lap = 118.576
# slowest lap = 785.081
# excluded over 562.8004735317343
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_18-Sepang International Circuit-FP3-Analysis.csv
# fastest lap = 118.761
# slowest lap = 730.093
# excluded over 513.955962699334
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_18-Sepang International Circuit-FP4-Analysis.csv
# fastest lap = 119.6
# slowest lap = 992.123
# excluded over 489.9320837016419
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_18-Sepang International Circuit-Q1-Analysis.csv
# fastest lap = 119.21600000000001
# slowest lap = 315.806
# excluded over 287.20377446487885
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_18-Sepang International Circuit-Q2-Analysis.csv
# fastest lap = 118.303
# slowest lap = 341.986
# excluded over 264.62005503385
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_18-Sepang International Circuit-WUP-Analysis.csv
# fastest lap = 119.51599999999999
# slowest lap = 303.572
# excluded over 192.14572187891608
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_19-Circuit Ricardo Tormo-FP1-Analysis.csv
# fastest lap = 91.455
# slowest lap = 783.738
# excluded over 494.27217666126637
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_19-Circuit Ricardo Tormo-FP2-Analysis.csv
# fastest lap = 90.735
# slowest lap = 940.448
# excluded over 503.0952526695453
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_19-Circuit Ricardo Tormo-FP3-Analysis.csv
# fastest lap = 90.232
# slowest lap = 660.081
# excluded over 433.4389651208263
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_19-Circuit Ricardo Tormo-FP4-Analysis.csv
# fastest lap = 90.48400000000001
# slowest lap = 637.711
# excluded over 317.5503928875803
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_19-Circuit Ricardo Tormo-Q1-Analysis.csv
# fastest lap = 90.538
# slowest lap = 343.286
# excluded over 311.7845769808623
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_19-Circuit Ricardo Tormo-Q2-Analysis.csv
# fastest lap = 89.97800000000001
# slowest lap = 362.086
# excluded over 301.1684441782983
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_19-Circuit Ricardo Tormo-WUP-Analysis.csv
# fastest lap = 91.136
# slowest lap = 357.581
# excluded over 185.5994458606107
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_2-Termas de Río Hondo-FP1-Analysis.csv
# fastest lap = 99.827
# slowest lap = 735.736
# excluded over 518.5821300047824
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_2-Termas de Río Hondo-FP2-Analysis.csv
# fastest lap = 99.181
# slowest lap = 704.669
# excluded over 492.9064144350418
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_2-Termas de Río Hondo-FP3-Analysis.csv
# fastest lap = 98.471
# slowest lap = 695.396
# excluded over 450.3656509740805
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_2-Termas de Río Hondo-FP4-Analysis.csv
# fastest lap = 99.34100000000001
# slowest lap = 624.762
# excluded over 360.62673171843824
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_2-Termas de Río Hondo-Q1-Analysis.csv
# fastest lap = 99.064
# slowest lap = 351.068
# excluded over 286.55459847377364
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_2-Termas de Río Hondo-Q2-Analysis.csv
# fastest lap = 98.304
# slowest lap = 360.496
# excluded over 299.7532361558865
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_2-Termas de Río Hondo-WUP-Analysis.csv
# fastest lap = 99.096
# slowest lap = 285.543
# excluded over 166.74259430725752
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_3-Circuit Of The Americas-FP1-Analysis.csv
# fastest lap = 125.311
# slowest lap = 849.878
# excluded over 506.45328098983555
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_3-Circuit Of The Americas-FP2-Analysis.csv
# fastest lap = 123.857
# slowest lap = 757.219
# excluded over 542.9170975954988
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_3-Circuit Of The Americas-FP4-Analysis.csv
# fastest lap = 125.478
# slowest lap = 957.5889999999999
# excluded over 681.0023353542955
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_3-Circuit Of The Americas-Q1-Analysis.csv
# fastest lap = 125.855
# slowest lap = 364.278
# excluded over 270.3275345863781
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_3-Circuit Of The Americas-Q2-Analysis.csv
# fastest lap = 123.787
# slowest lap = 453.362
# excluded over 298.5640935187254
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_3-Circuit Of The Americas-WUP-Analysis.csv
# fastest lap = 124.57300000000001
# slowest lap = 340.496
# excluded over 204.5157726414846
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_4-Circuito de Jerez-FP1-Analysis.csv
# fastest lap = 95.693
# slowest lap = 165.063
# excluded over 132.57756252827016
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_4-Circuito de Jerez-FP2-Analysis.csv
# fastest lap = 94.148
# slowest lap = 166.615
# excluded over 131.53948891622827
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_4-Circuito de Jerez-FP3-Analysis.csv
# fastest lap = 94.40299999999999
# slowest lap = 1080.63
# excluded over 243.44956413346853
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_4-Circuito de Jerez-FP4-Analysis.csv
# fastest lap = 94.066
# slowest lap = 219.607
# excluded over 134.61690905007382
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_4-Circuito de Jerez-Q1-Analysis.csv
# fastest lap = 94.69
# slowest lap = 156.261
# excluded over 145.41039946009778
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_4-Circuito de Jerez-Q2-Analysis.csv
# fastest lap = 94.09
# slowest lap = 162.202
# excluded over 139.1108569527959
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_4-Circuito de Jerez-WUP-Analysis.csv
# fastest lap = 95.489
# slowest lap = 148.378
# excluded over 130.5566990494337
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_5-Le Mans-FP1-Analysis.csv
# fastest lap = 90.977
# slowest lap = 776.957
# excluded over 493.27235229517737
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_5-Le Mans-FP2-Analysis.csv
# fastest lap = 91.018
# slowest lap = 991.754
# excluded over 506.5940202615549
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_5-Le Mans-FP3-Analysis.csv
# fastest lap = 102.49799999999999
# slowest lap = 1061.478
# excluded over 553.8683054182305
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_5-Le Mans-FP4-Analysis.csv
# fastest lap = 99.777
# slowest lap = 1428.4470000000001
# excluded over 1366.2007727199073
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_5-Le Mans-Q1-Analysis.csv
# fastest lap = 97.667
# slowest lap = 285.747
# excluded over 220.84123248210324
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_5-Le Mans-Q2-Analysis.csv
# fastest lap = 100.952
# slowest lap = 331.264
# excluded over 260.12077380628307
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_5-Le Mans-RAC-Analysis.csv
# fastest lap = 92.35499999999999
# slowest lap = 236.451
# excluded over 117.26364693497922
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_5-Le Mans-WUP-Analysis.csv
# fastest lap = 92.483
# slowest lap = 519.254
# excluded over 208.58012941949187
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_6-Autodromo Internazionale del Mugello-FP1-Analysis.csv
# fastest lap = 51.012
# slowest lap = 174.151
# excluded over 167.85559748832685
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_6-Autodromo Internazionale del Mugello-FP2-Analysis.csv
# fastest lap = 50.949
# slowest lap = 887.624
# excluded over 240.12379632883446
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_6-Autodromo Internazionale del Mugello-FP3-Analysis.csv
# fastest lap = 50.858
# slowest lap = 775.899
# excluded over 223.73816795402178
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_6-Autodromo Internazionale del Mugello-FP4-Analysis.csv
# fastest lap = 50.597
# slowest lap = 536.32
# excluded over 202.76931187417517
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_6-Autodromo Internazionale del Mugello-WUP-Analysis.csv
# fastest lap = 50.394
# slowest lap = 424.053
# excluded over 192.74703632575998
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_7-Circuit de Barcelona-FP1-Analysis.csv
# fastest lap = 100.69200000000001
# slowest lap = 713.766
# excluded over 492.4142083133605
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_7-Circuit de Barcelona-FP2-Analysis.csv
# fastest lap = 100.07900000000001
# slowest lap = 1056.176
# excluded over 518.6575248617465
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_7-Circuit de Barcelona-FP3-Analysis.csv
# fastest lap = 99.547
# slowest lap = 784.817
# excluded over 510.9537038350463
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_7-Circuit de Barcelona-FP4-Analysis.csv
# fastest lap = 100.235
# slowest lap = 528.121
# excluded over 318.94166045996076
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_7-Circuit de Barcelona-Q1-Analysis.csv
# fastest lap = 99.727
# slowest lap = 459.44
# excluded over 301.06116665266575
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_7-Circuit de Barcelona-Q2-Analysis.csv
# fastest lap = 99.48400000000001
# slowest lap = 299.081
# excluded over 272.90207732142267
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_7-Circuit de Barcelona-RAC-Analysis.csv
# fastest lap = 100.507
# slowest lap = 396.967
# excluded over 152.778835729638
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_7-Circuit de Barcelona-WUP-Analysis.csv
# fastest lap = 99.918
# slowest lap = 733.693
# excluded over 248.9820316116133
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_8-TT Circuit Assen-FP1-Analysis.csv
# fastest lap = 93.90899999999999
# slowest lap = 678.713
# excluded over 478.6335801975496
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_8-TT Circuit Assen-FP2-Analysis.csv
# fastest lap = 92.638
# slowest lap = 761.5840000000001
# excluded over 502.5265203276555
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_8-TT Circuit Assen-FP3-Analysis.csv
# fastest lap = 92.471
# slowest lap = 818.858
# excluded over 452.2506308045548
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_8-TT Circuit Assen-FP4-Analysis.csv
# fastest lap = 92.952
# slowest lap = 492.481
# excluded over 339.041551757279
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_8-TT Circuit Assen-Q1-Analysis.csv
# fastest lap = 92.71000000000001
# slowest lap = 385.866
# excluded over 348.3655827808474
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_8-TT Circuit Assen-Q2-Analysis.csv
# fastest lap = 92.017
# slowest lap = 403.44100000000003
# excluded over 316.4880857206391
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_8-TT Circuit Assen-RAC-Analysis.csv
# fastest lap = 93.712
# slowest lap = 147.8
# excluded over 105.61565139190782
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_8-TT Circuit Assen-WUP-Analysis.csv
# fastest lap = 93.67699999999999
# slowest lap = 524.201
# excluded over 263.4161947712447
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_9-Sachsenring-FP1-Analysis.csv
# fastest lap = 81.39
# slowest lap = 739.975
# excluded over 452.89229028154136
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_9-Sachsenring-FP2-Analysis.csv
# fastest lap = 80.705
# slowest lap = 861.817
# excluded over 453.75817351945176
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_9-Sachsenring-FP3-Analysis.csv
# fastest lap = 80.34700000000001
# slowest lap = 772.924
# excluded over 459.99697584567434
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_9-Sachsenring-FP4-Analysis.csv
# fastest lap = 81.15299999999999
# slowest lap = 645.499
# excluded over 339.8551172644203
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_9-Sachsenring-Q1-Analysis.csv
# fastest lap = 80.93299999999999
# slowest lap = 336.284
# excluded over 270.68969588080625
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_9-Sachsenring-Q2-Analysis.csv
# fastest lap = 80.195
# slowest lap = 714.453
# excluded over 371.2526715987832
#
#
# C:/Users/LuciusFish/Desktop/motoFiles/csvFiles/sessions/2019-MotoGP-Round_9-Sachsenring-WUP-Analysis.csv
# fastest lap = 83.116
# slowest lap = 1176.189
# excluded over 627.6343318893889
#
#
#
#
# Finished
